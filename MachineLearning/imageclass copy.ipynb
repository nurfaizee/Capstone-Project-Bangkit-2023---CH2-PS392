# %%
import tensorflow as tf 
import os

# %%
apple_dir='/Users/muhammadzuamaalamin/Documents/Imageclass/Fruits Classification/train/Apple'
banana_dir='/Users/muhammadzuamaalamin/Documents/Imageclass/Fruits Classification/train/Banana'
grape_dir='/Users/muhammadzuamaalamin/Documents/Imageclass/Fruits Classification/train/Grape'
mango_dir='/Users/muhammadzuamaalamin/Documents/Imageclass/Fruits Classification/train/Mango'
strawberry_dir='/Users/muhammadzuamaalamin/Documents/Imageclass/Fruits Classification/train/Strawberry'

print(len(os.listdir(apple_dir)))
print(len(os.listdir(banana_dir)))
print(len(os.listdir(mango_dir)))
print(len(os.listdir(strawberry_dir)))
print(len(os.listdir(grape_dir)))
# Out:
# 1552
# 1552
# 1552
# 1552
# 1552

# %%
# import os
# import shutil
# from sklearn.model_selection import train_test_split

# # Function to create a new directory
# def create_directory(directory):
#     if not os.path.exists(directory):
#         os.makedirs(directory)

# # Function to move files to a new directory
# def move_files(src_dir, files, dest_dir):
#     create_directory(dest_dir)
#     for file in files:
#         src_path = os.path.join(src_dir, file)
#         dest_path = os.path.join(dest_dir, file)
#         shutil.move(src_path, dest_path)

# # Update the split_data function to include destination directory
# def split_data(train_dir, validation_percentage=0.2, dest_dir=None):
#     files = os.listdir(train_dir)
#     train_files, validation_files = train_test_split(files, test_size=validation_percentage, random_state=42)

#     if dest_dir:
#         move_files(train_dir, validation_files, dest_dir)

#     return train_files, validation_files

# # Define new directories for validation data
# apple_validation_dir = '/Users/muhammadzuamaalamin/Documents/Imageclass/Fruits Classification/validation/Apple'
# banana_validation_dir = '/Users/muhammadzuamaalamin/Documents/Imageclass/Fruits Classification/validation/Banana'
# grape_validation_dir = '/Users/muhammadzuamaalamin/Documents/Imageclass/Fruits Classification/validation/Grape'
# mango_validation_dir = '/Users/muhammadzuamaalamin/Documents/Imageclass/Fruits Classification/validation/Mango'
# strawberry_validation_dir = '/Users/muhammadzuamaalamin/Documents/Imageclass/Fruits Classification/validation/Strawberry'

# # Call the split_data function with destination directories
# apple_train, apple_validation = split_data(apple_dir, dest_dir=apple_validation_dir)
# banana_train, banana_validation = split_data(banana_dir, dest_dir=banana_validation_dir)
# grape_train, grape_validation = split_data(grape_dir, dest_dir=grape_validation_dir)
# mango_train, mango_validation = split_data(mango_dir, dest_dir=mango_validation_dir)
# strawberry_train, strawberry_validation = split_data(strawberry_dir, dest_dir=strawberry_validation_dir)

# # Print the updated counts
# print(f"Train Apple: {len(apple_train)} | Validation Apple: {len(apple_validation)}")
# print(f"Train Banana: {len(banana_train)} | Validation Banana: {len(banana_validation)}")
# print(f"Train Grape: {len(grape_train)} | Validation Grape: {len(grape_validation)}")
# print(f"Train Mango: {len(mango_train)} | Validation Mango: {len(mango_validation)}")
# print(f"Train Strawberry: {len(strawberry_train)} | Validation Strawberry: {len(strawberry_validation)}")
# Out:
# Train Apple: 1552 | Validation Apple: 388
# Train Banana: 1552 | Validation Banana: 388
# Train Grape: 1552 | Validation Grape: 388
# Train Mango: 1552 | Validation Mango: 388
# Train Strawberry: 1552 | Validation Strawberry: 388

# %%
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# # Inisialisasi ImageDataGenerator untuk augmentasi gambar
# datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
# # Menentukan ukuran gambar yang diharapkan dan batch size
# img_size = (180, 180)
# batch_size = 32

# %%
# Memuat dan mengaugmentasi data train
train_dir="/Users/muhammadzuamaalamin/Documents/Imageclass/Fruits Classification/train"
#train_generator = datagen.flow_from_directory(train_dir,
                                            #   target_size=img_size, batch_size=batch_size, class_mode='categorical')
validation_dir="/Users/muhammadzuamaalamin/Documents/Imageclass/Fruits Classification/validation"
# Memuat dan mengaugmentasi data validation
#validation_generator = datagen.flow_from_directory(validation_dir,
                                                #    target_size=img_size, batch_size=batch_size, class_mode='categorical')

# %%
# training_set = tf.keras.utils.image_dataset_from_directory(
#     train_dir,
#     label_mode='categorical',
#     class_names=None,
#     color_mode='rgb',
#     batch_size=32,
#     image_size=(180, 180),
#     shuffle=True,
#     seed=None,
#     subset=None,
#     validation_split=None,
#     interpolation='bilinear',  # Corrected parameter name
#     follow_links=False,
#     crop_to_aspect_ratio=False
# )
# Out:
# Found 7760 files belonging to 5 classes.

# %%
# validation_set = tf.keras.utils.image_dataset_from_directory(
#     validation_dir,
#     label_mode='categorical',
#     class_names=None,
#     color_mode='rgb',
#     batch_size=32,
#     image_size=(180, 180),
#     shuffle=True,
#     seed=None,
#     subset=None,
#     validation_split=None,
#     interpolation='bilinear',  # Corrected parameter name
#     follow_links=False,
#     crop_to_aspect_ratio=False
# )

# %%
# Corrected import statement for ImageDataGenerator
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Example of data augmentation with the corrected import
training_datagen = ImageDataGenerator(
    rescale=1. / 255,
    rotation_range=40,
    horizontal_flip=True,
    shear_range=0.2,
    zoom_range=0.2,
    fill_mode='nearest'
)

validation_datagen = ImageDataGenerator(rescale=1.0 / 255.)

# %%
train_generator=training_datagen.flow_from_directory(directory=train_dir,
                                                  target_size=(128,128),
                                                  batch_size=32,
                                                  shuffle=True,
                                                  class_mode='categorical')
validation_generator=validation_datagen.flow_from_directory(directory=validation_dir,
                                                  target_size=(128,128),
                                                  batch_size=32,
                                                  shuffle=True,
                                                  class_mode='categorical')
# Out:
# Found 7760 images belonging to 5 classes.
# Found 1940 images belonging to 5 classes.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(filters=8, kernel_size=3, input_shape=(128, 128, 3)),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.BatchNormalization(),
    
    tf.keras.layers.Conv2D(filters=16, kernel_size=3),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.MaxPooling2D(pool_size=2, strides=2),
    
    tf.keras.layers.Conv2D(filters=24, kernel_size=3),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.Conv2D(filters=32, kernel_size=3),
    tf.keras.layers.Activation('relu'),
    
    tf.keras.layers.Conv2D(filters=48, kernel_size=3),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.MaxPooling2D(pool_size=2, strides=2),
    
    tf.keras.layers.Flatten(),
    
    tf.keras.layers.Dense(units=128),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.Dropout(0.25),
    
    tf.keras.layers.Dense(units=64),
    tf.keras.layers.Activation('relu'),
    
    tf.keras.layers.Dense(units=5, activation='softmax')
])

optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=0.001)

model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_30 (Conv2D)          (None, 126, 126, 8)       224
#
#  activation_46 (Activation)  (None, 126, 126, 8)       0
#
#  batch_normalization_4 (Bat  (None, 126, 126, 8)       32
#  chNormalization)
#
#  conv2d_31 (Conv2D)          (None, 124, 124, 16)      1168
#
#  activation_47 (Activation)  (None, 124, 124, 16)      0
#
#  max_pooling2d_12 (MaxPooli  (None, 62, 62, 16)        0
#  ng2D)
#
#  conv2d_32 (Conv2D)          (None, 60, 60, 24)        3480
#
#  activation_48 (Activation)  (None, 60, 60, 24)        0
#
#  conv2d_33 (Conv2D)          (None, 58, 58, 32)        6944
#
#  activation_49 (Activation)  (None, 58, 58, 32)        0
#
#  conv2d_34 (Conv2D)          (None, 56, 56, 48)        13872
#
#  activation_50 (Activation)  (None, 56, 56, 48)        0
#
#  max_pooling2d_13 (MaxPooli  (None, 28, 28, 48)        0
# ...

# %%
# # Mengompilasi model
# # from tensorflow.keras.optimizers import Adam
# model.compile(optimizer='adam',
#                   loss='categorical_crossentropy',
#                   metrics=['accuracy'])

# %%
# class myCallback(tf.keras.callbacks.Callback):
#     def on_epoch_end(self, epoch, logs={}):
#         if (logs.get('accuracy') >= 0.9 and logs.get('val_accuracy') >= 0.9):
#             print("\n accuracy and validation_accuracy > 83%, stop training !!!")
#             self.model.stop_training = True

# Callback = myCallback()

# %%
epochs = 50
history = model.fit(
  train_generator,
  validation_data=validation_generator,
  epochs=epochs
)
# Out:
# Epoch 1/50
# 243/243 [==============================] - 41s 169ms/step - loss: 1.3540 - accuracy: 0.4063 - val_loss: 1.3118 - val_accuracy: 0.5021
# Epoch 2/50
# 243/243 [==============================] - 42s 171ms/step - loss: 1.1031 - accuracy: 0.5329 - val_loss: 1.0934 - val_accuracy: 0.5588
# Epoch 3/50
# 243/243 [==============================] - 40s 166ms/step - loss: 1.0429 - accuracy: 0.5781 - val_loss: 0.9982 - val_accuracy: 0.5918
# Epoch 4/50
# 243/243 [==============================] - 40s 165ms/step - loss: 0.9840 - accuracy: 0.6044 - val_loss: 0.9605 - val_accuracy: 0.6278
# Epoch 5/50
# 243/243 [==============================] - 40s 165ms/step - loss: 0.9558 - accuracy: 0.6171 - val_loss: 0.9893 - val_accuracy: 0.6031
# Epoch 6/50
# 243/243 [==============================] - 40s 165ms/step - loss: 0.9330 - accuracy: 0.6406 - val_loss: 0.8724 - val_accuracy: 0.6495
# Epoch 7/50
# ...

# %%
import matplotlib.pyplot as plt

# Plot the results
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()

plt.show()

# %%
epochs = range(len(acc))

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend(loc=0)
plt.figure()

plt.show()

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

# Path gambar yang akan diprediksi
image_path = '/Users/muhammadzuamaalamin/Documents/Capstone/WhatsApp Image 2023-12-15 at 19.56.49.jpeg'  # Ganti dengan path gambar yang ingin Anda prediksi

# Membaca gambar
img = image.load_img(image_path, target_size=(128, 128))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)  # Menambah dimensi batch
plt.imshow(img)
plt.show()

# Normalisasi nilai pixel
img_array /= 255.0

# Melakukan prediksi
predictions = model.predict(img_array)

# Mendapatkan kelas dengan probabilitas tertinggi
predicted_class = np.argmax(predictions[0])

# Mendapatkan label kelas dari generator
class_labels = list(train_generator.class_indices.keys())

# Menampilkan hasil prediksi
print(f'Predicted class: {class_labels[predicted_class]}')
print(f'Predicted probabilities: {predictions[0]}')
# Out:
# 1/1 [==============================] - 0s 61ms/step
# Predicted class: Mango
# Predicted probabilities: [2.2545841e-03 4.5849082e-01 2.8760738e-03 5.3637654e-01 2.0019838e-06]

# %%
train_generator.class_indices.keys()
# Out:
# dict_keys(['Apple', 'Banana', 'Grape', 'Mango', 'Strawberry'])

# %%
model.save("hasil_model_fix_jadi.h5")
# Out:
# /opt/homebrew/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
